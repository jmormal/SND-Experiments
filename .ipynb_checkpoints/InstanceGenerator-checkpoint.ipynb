# %%
class SCNode():
    def __init__(self, x,y):
        self.x = x
        self.y = y 
        self.full_routes = []

    

class IndustrialZone():
    def __init__(self, x,y):
        self.x = x
        self.y = y

class InstanceGenerator():
    def __init__(self, industrial_zones, L, V):
        self.industrial_zones = industrial_zones
        self.L = { [] for i in range(L)} 
        self.V = list(range(V))
    def assign_

# %%
import pandas as pd

# %%
a= InstanceGenerator(2,3)
a.L
# Out:
# 3
